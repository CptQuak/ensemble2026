# %%
import pandas as pd

# %%
df = pd.read_parquet("data/chebi_submission_example.parquet", engine='fastparquet')

# %%
df
# Out:
#           mol_id                                             SMILES  class_0  \
# 0       mol_6861  OC[C@H]1O[C@H](O[C@H]2C(O)O[C@H](CO)[C@@H](O)[...        0
# 1      mol_29793  O.O=C([O-])CC(O)(CC(=O)[O-])C(=O)[O-].[K+].[K+...        1
# 2      mol_26953  CC(C)=CCC/C(C)=C/CC/C(C)=C/CC/C(C)=C\CC/C(C)=C...        1
# 3      mol_26053                                  C=C1CCC(C(C)C)CC1        1
# 4      mol_18653                                   O=C(O)C1CCCCC1=O        0
# ...          ...                                                ...      ...
# 11218  mol_13480                                 Oc1cc2cc[nH]c2cc1O        0
# 11219  mol_42067  CNCC(=O)OCc1cccnc1N(C)C(=O)OC(C)[n+]1cnn(C[C@]...        1
# 11220  mol_43978           N[C@@H](CCC(=O)[O-])C(O)=Nc1ccc2ccccc2c1        1
# 11221  mol_16268  COc1cc(-c2[o+]c3cc(O)cc(O)c3cc2O[C@@H]2O[C@H](...        0
# 11222  mol_36270                            CCCCCCC=CCCCCCCCCC(=O)O        0
#
# ...

# %%
test_df = pd.read_parquet('data/chebi_dataset_test_empty.parquet', engine='fastparquet')

# %%
test_df
# Out:
#           mol_id                                             SMILES
# 0       mol_6861  OC[C@H]1O[C@H](O[C@H]2C(O)O[C@H](CO)[C@@H](O)[...
# 1      mol_29793  O.O=C([O-])CC(O)(CC(=O)[O-])C(=O)[O-].[K+].[K+...
# 2      mol_26953  CC(C)=CCC/C(C)=C/CC/C(C)=C/CC/C(C)=C\CC/C(C)=C...
# 3      mol_26053                                  C=C1CCC(C(C)C)CC1
# 4      mol_18653                                   O=C(O)C1CCCCC1=O
# ...          ...                                                ...
# 11218  mol_13480                                 Oc1cc2cc[nH]c2cc1O
# 11219  mol_42067  CNCC(=O)OCc1cccnc1N(C)C(=O)OC(C)[n+]1cnn(C[C@]...
# 11220  mol_43978           N[C@@H](CCC(=O)[O-])C(O)=Nc1ccc2ccccc2c1
# 11221  mol_16268  COc1cc(-c2[o+]c3cc(O)cc(O)c3cc2O[C@@H]2O[C@H](...
# 11222  mol_36270                            CCCCCCC=CCCCCCCCCC(=O)O
#
# [11223 rows x 2 columns]
