# %%
import polars as pl

# %%
df = pl.scan_csv('data/data.csv')

# %%
df.head(5).collect()
# Out:
# shape: (5, 20)
# ┌───────────────────────┬───────────────────────┬────────┬──────┬───┬─────┬─────┬─────┬────────────┐
# │ deviceId              ┆ timedate              ┆ period ┆ t1   ┆ … ┆ x1  ┆ x2  ┆ x3  ┆ deviceType │
# │ ---                   ┆ ---                   ┆ ---    ┆ ---  ┆   ┆ --- ┆ --- ┆ --- ┆ ---        │
# │ str                   ┆ str                   ┆ str    ┆ f64  ┆   ┆ f64 ┆ f64 ┆ i64 ┆ i64        │
# ╞═══════════════════════╪═══════════════════════╪════════╪══════╪═══╪═════╪═════╪═════╪════════════╡
# │ 000cc3cb7f030c3d0c481 ┆ 2024-10-01 00:00:00   ┆ train  ┆ 0.29 ┆ … ┆ 0.0 ┆ 0.0 ┆ 8   ┆ 19         │
# │ bd0e7cf42…            ┆ UTC                   ┆        ┆      ┆   ┆     ┆     ┆     ┆            │
# │ 000cc3cb7f030c3d0c481 ┆ 2024-10-01 00:05:00   ┆ train  ┆ 0.29 ┆ … ┆ 0.0 ┆ 0.0 ┆ 8   ┆ 19         │
# │ bd0e7cf42…            ┆ UTC                   ┆        ┆      ┆   ┆     ┆     ┆     ┆            │
# ...
